# %%
import pandas as pd
import plotly.express as px

# %%
df = pd.read_parquet("../scenario_outputs/2024_10_17_13_51_09_scenarios.parquet").reset_index(drop=True)
df
# Out:
#         granular_ds  granular_temperature  granular_nominal_temperature  \
# 0        2015-01-01             -0.002641                      9.994652
# 1        2015-01-02             -0.017001                      6.967103
# 2        2015-01-03             -0.028726                      4.495221
# 3        2015-01-04             -0.040889                      1.930792
# 4        2015-01-05             -0.017712                      6.817229
# ...             ...                   ...                           ...
# 2373595  2031-03-27              0.001765                     10.923510
# 2373596  2031-03-28             -0.019414                      6.458472
# 2373597  2031-03-29             -0.026488                      4.966899
# 2373598  2031-03-30             -0.049621                      0.089799
# 2373599  2031-03-31             -0.013273                      7.753096
#
#          granular_hdd  granular_nominal_hdd  granular_cdd  \
# ...
